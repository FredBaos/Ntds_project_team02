# %% [markdown]
# # Exploration
#
# In his notebook, you have all the tools necessary to analyze a given graph, constructed from a dataset given as input. <br/>

# %% [markdown]
# ## Table of contents
# 1. [Loading dataset](#Part-I:-Loading-dataset)
# 2. [Graph properties](#Part-II:-Graph-properties)
# 3. [Type of graph identification](#Part-III:-Type-of-graph-identification)
# 4. [Nodes properties](#Part-IV:-Nodes-properties)
# 5. [Attributes analysis](#Part-V:-Attributes-analysis)

# %% [markdown]
# ## Part I: Loading dataset

# %%
# Standard librairies
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import operator
import collections
from collections import Counter
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %matplotlib inline

# %%
df = pd.read_csv("space_data.tsv", sep = "\t")
df.head()
# Out:
#               source                                         target  depth
# 0  space exploration  discovery and exploration of the solar system      1
# 1  space exploration               in-space propulsion technologies      1
# 2  space exploration                             robotic spacecraft      1
# 3  space exploration              timeline of planetary exploration      1
# 4  space exploration                      landings on other planets      1

# %%
G = nx.from_pandas_edgelist(df, "source", "target", edge_attr=True, create_using=nx.Graph())

# %%
nx.draw(G)
# Out:
# /home/frederic/anaconda3/envs/ntds/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# ## Part II: Graph properties

# %%
# computation of the number of connected components of the graph
n_cc = nx.number_connected_components(G)
print("The graph has", n_cc, "connected components.")
# Out:
# The graph has 1 connected components.

# %%
# computation of the diameter of the graph
A = nx.adjacency_matrix(G)
diam = nx.diameter(G)
print("The graph has a diameter of", diam, ".")
# Out:
# The graph has a diameter of 8 .

# %% [markdown]
# ## Part III: Type of graph identification

# %%
# study of the degree distribution of the graph
degree_sequence = sorted([d for n, d in G.degree()], reverse=True) 

plt.figure(figsize=(10,7))
sns.distplot(degree_sequence[int(len(degree_sequence) * 0.005):], kde=False, hist_kws={'log':True})
plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
plt.show()

# %% [markdown]
# This network seems to be a scale-free network, as its degree distribution follows a power law.

# %% [markdown]
# ## Part IV: Nodes properties

# %%
# clustering coefficients of the nodes 
clus_coefs = nx.clustering(G)
sorted_clus_coefs = collections.OrderedDict(sorted(clus_coefs.items(), key=operator.itemgetter(1), reverse=True))
print("Top 20 nodes with highest clustering coefficient:")
list(sorted_clus_coefs.items())[:20]
# Out:
# Top 20 nodes with highest clustering coefficient:
# [('mars probe program', 1.0),
#  ('phobos program', 1.0),
#  ('microgravity university', 1.0),
#  ('renal stone formation in space', 1.0),
#  ('space nursing', 1.0),
#  ('moon treaty', 1.0),
#  ('chinese exclusion policy of nasa', 1.0),
#  ('high-altitude nuclear explosion', 1.0),
#  ('anti-gravity', 1.0),
#  ('lists of rockets', 1.0),
#  ('spaceport', 1.0),
#  ('space climate', 1.0),
#  ('nuclear propulsion', 1.0),
#  ('aerospace architecture', 1.0),
#  ('space flight participant', 1.0),
#  ('safran', 1.0),
#  ('thales alenia space', 1.0),
#  ('musée aéronautique et spatial safran', 1.0),
#  ('cannes mandelieu space center', 1.0),
#  ('space adventures', 1.0)]

# %%
# clustering coefficients distribution
cc_sequence = list(clus_coefs.values())

plt.figure(figsize=(10,7))
sns.distplot(cc_sequence, kde=False, hist_kws={'log':True}, bins=10)
plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Clustering coefficient")
plt.show()

# %%
# study of the centrality of the nodes
cent = nx.degree_centrality(G)
sorted_cent = collections.OrderedDict(sorted(cent.items(), key=operator.itemgetter(1), reverse=True))
print("Top 20 nodes with highest centrality:")
list(sorted_cent.items())[:20]
# Out:
# Top 20 nodes with highest centrality:
# [('space exploration', 0.043603258265452804),
#  ('space colonization', 0.01964542405366555),
#  ('private spaceflight', 0.019166267369429803),
#  ('space science', 0.018687110685194058),
#  ('rocket', 0.01772879731672257),
#  ('remote sensing', 0.017249640632486823),
#  ('newspace', 0.016291327264015335),
#  ('effect of spaceflight on the human body', 0.015333013895543843),
#  ('french space program', 0.014374700527072353),
#  ('exploration of mars', 0.013895543842836608),
#  ('colonization of mars', 0.013895543842836608),
#  ('timeline of solar system exploration', 0.013416387158600863),
#  ('global catastrophic risks', 0.013416387158600863),
#  ('space medicine', 0.012937230474365118),
#  ('energy development', 0.012458073790129373),
#  ('space shuttle', 0.012458073790129373),
#  ('mars to stay', 0.011978917105893628),
#  ('augustin-jean fresnel', 0.011978917105893628),
#  ('energy policy of india', 0.011978917105893628),
#  ('astrobiology', 0.011978917105893628)]

# %% [markdown]
# ## Part V: Attributes analysis

# %%
# community detection within the nodes attributes
communities = list(nx.algorithms.community.label_propagation.label_propagation_communities(G))
print("Some communities:")
print(communities[0])
print(communities[1])

# computation of average centrality among communities
avg_cent = []
for com in communities:
    G_tmp = G.subgraph(com)
    cent = nx.degree_centrality(G_tmp)
    avg_cent.append(np.mean(list(cent.values())))
    
# box plot to have a representation of the average centrality among communities
plt.figure(figsize=(10,7))
plt.title("Distribution of average centrality of communities")
sns.boxplot(avg_cent)
plt.show()
# Out:
# Some communities:
# {'david melgueiro', 'russian explorers', 'transpolar sea route', 'arctic shipping routes', 'northwest passage', 'russian geographical society', 'arctic bridge', 'territorial claims in the arctic', 'great northern expedition', 'northern sea route'}
# {'arctic policy of russia', 'arctic council', 'chief directorate of the northern sea route', 'arctic policy of canada', 'continental shelf of russia', 'extreme north (russia)', 'russian irredentism', 'arctic cooperation and politics', 'greenpeace arctic sunrise ship case', 'arctic policy of china', 'norway–russia border'}

# %%
# some basic NLP to study nodes attributes
nodes_emb = list(G.nodes)
print("Some nodes embeddings:")
print(nodes_emb[:10])

# get the list of all the words from the articles titles
nodes_emb_flattened = [word for line in nodes_emb for word in line.split()]

# initialize a dict that counts the words occurences
counts = Counter(nodes_emb_flattened)
print("\nSome entries of the dictionnary that counts the words occurences:")
print(list(counts.items())[:7])
# Out:
# Some nodes embeddings:
# ['space exploration', 'discovery and exploration of the solar system', 'in-space propulsion technologies', 'robotic spacecraft', 'timeline of planetary exploration', 'landings on other planets', 'pioneer program', 'luna program', 'zond program', 'venera program']
#
# Some entries of the dictionnary that counts the words occurences:
# [('space', 211), ('exploration', 29), ('discovery', 3), ('and', 70), ('of', 203), ('the', 101), ('solar', 28)]

# %%
# creation and generation of a word cloud image, which displays words with sizes proportional to their occurences
wordcloud = WordCloud().generate((" ").join(nodes_emb))

plt.figure(figsize=(17,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
