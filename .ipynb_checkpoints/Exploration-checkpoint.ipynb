# %%
import numpy as np
from scipy.spatial.distance import pdist, squareform
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random
import pandas as pd
import networkx as nx

# %matplotlib inline

# %% [markdown]
# ## using input that has the same format

# %%
df = pd.read_csv("space_data.tsv", sep = "\t")
df.head()
# Out:
#               source                                         target  depth
# 0  space exploration  discovery and exploration of the solar system      1
# 1  space exploration               in-space propulsion technologies      1
# 2  space exploration                             robotic spacecraft      1
# 3  space exploration              timeline of planetary exploration      1
# 4  space exploration                      landings on other planets      1

# %%
G = nx.from_pandas_edgelist(df, "source", "target", edge_attr=True, create_using=nx.Graph())

# %%
nx.draw(G)
# Out:
# /home/frederic/anaconda3/envs/ntds/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# ## compute number of connected components

# %%
n_cc = nx.number_connected_components(G)
n_cc
# Out:
# 1

# %% [markdown]
# ## compute diameter

# %%
A = nx.adjacency_matrix(G)
A
# Out:
# <2088x2088 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6356 stored elements in Compressed Sparse Row format>

# %%
diam = nx.diameter(G)
diam
# Out:
# 8

# %% [markdown]
# ## degree distribution

# %%
import seaborn as sns

# %%
degree_sequence = sorted([d for n, d in G.degree()], reverse=True) 
plt.figure(figsize=(10,7))
sns.distplot(degree_sequence, kde=False, color='black')
plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
plt.show()

# %%
#log, virer outliers de droite

# %% [markdown]
# ## clustering coefficient

# %%
clus_coefs = nx.clustering(G)
clus_coefs
# Out:
# {'space exploration': 0.029548229548229547,
#  'discovery and exploration of the solar system': 0.5,
#  'in-space propulsion technologies': 0.08771929824561403,
#  'robotic spacecraft': 0.10256410256410256,
#  'timeline of planetary exploration': 0.05555555555555555,
#  'landings on other planets': 0,
#  'pioneer program': 0.35714285714285715,
#  'luna program': 0.1,
#  'zond program': 0,
#  'venera program': 0.2,
#  'mars probe program': 1.0,
#  'ranger program': 0.35714285714285715,
#  'mariner program': 0.2,
#  'surveyor program': 0.3333333333333333,
#  'viking program': 0.2761904761904762,
#  'voyager program': 0.19047619047619047,
#  'vega program': 0.3333333333333333,
#  'phobos program': 1.0,
#  'discovery program': 0,
#  'chandrayaan-1': 0.16666666666666666,
#  'mars orbiter mission': 0.3,
#  'chinese lunar exploration program': 0,
#  'astrobotic technology': 0.19047619047619047,
#  'interplanetary contamination': 0.16666666666666666,
# ...

# %% [markdown]
# ## centrality

# %%
import operator
import collections

# %%
cent = nx.degree_centrality(G)

# %%
sorted_cent = collections.OrderedDict(sorted(cent.items(), key=operator.itemgetter(1), reverse=True))
sorted_cent
# Out:
# OrderedDict([('space exploration', 0.043603258265452804),
#              ('space colonization', 0.01964542405366555),
#              ('private spaceflight', 0.019166267369429803),
#              ('space science', 0.018687110685194058),
#              ('rocket', 0.01772879731672257),
#              ('remote sensing', 0.017249640632486823),
#              ('newspace', 0.016291327264015335),
#              ('effect of spaceflight on the human body', 0.015333013895543843),
#              ('french space program', 0.014374700527072353),
#              ('exploration of mars', 0.013895543842836608),
#              ('colonization of mars', 0.013895543842836608),
#              ('timeline of solar system exploration', 0.013416387158600863),
#              ('global catastrophic risks', 0.013416387158600863),
#              ('space medicine', 0.012937230474365118),
#              ('energy development', 0.012458073790129373),
#              ('space shuttle', 0.012458073790129373),
# ...

# %% [markdown]
# ## community detection

# %%
# found here: https://towardsdatascience.com/learning-in-graphs-with-python-part-3-8d5513eef62d
communities = list(nx.algorithms.community.label_propagation.label_propagation_communities(G))
communities
# Out:
# [{'arctic bridge',
#   'arctic shipping routes',
#   'david melgueiro',
#   'great northern expedition',
#   'northern sea route',
#   'northwest passage',
#   'russian explorers',
#   'russian geographical society',
#   'territorial claims in the arctic',
#   'transpolar sea route'},
#  {'arctic cooperation and politics',
#   'arctic council',
#   'arctic policy of canada',
#   'arctic policy of china',
#   'arctic policy of russia',
#   'chief directorate of the northern sea route',
#   'continental shelf of russia',
#   'extreme north (russia)',
#   'greenpeace arctic sunrise ship case',
#   'norway–russia border',
#   'russian irredentism'},
#  {'1966 soviet submarine global circumnavigation',
#   'operation sandblast',
#   'operation sea orbit'},
#  {'bulk cargo',
#   'bulk liquids',
#   'bulk materials',
#   'conflict resource',
#   'marginal factor cost',
#   'material passport',
#   'natural resource',
#   'raw material',
#   'waste management'},
#  {'aircraft',
# ...

# %%
avg_cent = []
for com in communities:
    G_tmp = G.subgraph(com)
    cent = nx.degree_centrality(G_tmp)
    avg_cent.append(np.mean(list(cent.values())))

# %%
plt.figure(figsize=(10,7))
plt.title("Distribution of average centrality of communities")
sns.boxplot(avg_cent)
plt.show()

# %% [markdown]
# ## NLP simple analysis of the attributes
# ### a) word count

# %%
from collections import Counter

# %%
nodes_emb = list(G.nodes)
nodes_emb
# Out:
# ['space exploration',
#  'discovery and exploration of the solar system',
#  'in-space propulsion technologies',
#  'robotic spacecraft',
#  'timeline of planetary exploration',
#  'landings on other planets',
#  'pioneer program',
#  'luna program',
#  'zond program',
#  'venera program',
#  'mars probe program',
#  'ranger program',
#  'mariner program',
#  'surveyor program',
#  'viking program',
#  'voyager program',
#  'vega program',
#  'phobos program',
#  'discovery program',
#  'chandrayaan-1',
#  'mars orbiter mission',
#  'chinese lunar exploration program',
#  'astrobotic technology',
#  'interplanetary contamination',
#  'animals in space',
#  'monkeys in space',
#  'russian space dogs',
#  'astronaut',
#  'vostok program',
#  'mercury program',
#  'voskhod program',
#  'gemini program',
#  'soyuz program',
#  'apollo program',
#  'salyut',
#  'skylab',
#  'space shuttle program',
#  'mir',
#  'international space station',
#  'vision for space exploration',
# ...

# %%
nodes_emb_flattened = [word for line in nodes_emb for word in line.split()]

# %%
counts = Counter(nodes_emb_flattened)
counts
# Out:
# Counter({'space': 211,
#          'exploration': 29,
#          'discovery': 3,
#          'and': 70,
#          'of': 203,
#          'the': 101,
#          'solar': 28,
#          'system': 34,
#          'in-space': 1,
#          'propulsion': 13,
#          'technologies': 4,
#          'robotic': 4,
#          'spacecraft': 14,
#          'timeline': 28,
#          'planetary': 9,
#          'landings': 2,
#          'on': 38,
#          'other': 1,
#          'planets': 5,
#          'pioneer': 7,
#          'program': 48,
#          'luna': 3,
#          'zond': 2,
#          'venera': 2,
#          'mars': 69,
#          'probe': 3,
#          'ranger': 2,
#          'mariner': 5,
#          'surveyor': 2,
#          'viking': 2,
#          'voyager': 3,
#          'vega': 1,
#          'phobos': 1,
#          'chandrayaan-1': 1,
#          'orbiter': 12,
#          'mission': 16,
#          'chinese': 5,
#          'lunar': 29,
#          'astrobotic': 1,
# ...

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

to_wc = nodes_emb
to_wc =(" ").join(to_wc)

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(to_wc)

# Display the generated image:
plt.figure(figsize=(17,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# checker grading pour format
# creer script pour print tout et enregistrer plots + images
# clean notebook, utiliser md pour bonnifier
