# %%
#pip3 install notebook ipywidgets plotly
#jupyter nbextension enable --py widgetsnbextension
#jupyter nbextension enable --py plotlywidget

# %%
import igraph as ig
import pandas as pd
import webbrowser
import json
import urllib.request
import chart_studio.plotly as py
import plotly.graph_objs as go
from ipywidgets import widgets

from utils import *
from exploitation.predict import *
from config import *

# %% [markdown]
# This visualization is inspired from plotly officiel tutorials: https://plot.ly/python/v3/3d-network-graph/

# %%
#Load data for the graph
df_node = pd.read_csv(os.path.join(GENERATED_DATA_PATH,DF_NODE_FILENAME)).drop('Unnamed: 0',axis=1)
df_edge = pd.read_csv(os.path.join(GENERATED_DATA_PATH,DF_EDGE_FILENAME)).drop('Unnamed: 0',axis=1)

# %%
df_node.head()
# Out:
#                         name  \
# 0          intelligent agent
# 1                    chatbot
# 2  artificial neural network
# 3    artificial intelligence
# 4                    weak ai
#
#                                                  url  \
# 0    https://en.wikipedia.org/wiki/Intelligent_agent
# 1              https://en.wikipedia.org/wiki/Chatbot
# 2  https://en.wikipedia.org/wiki/Artificial_neura...
# 3  https://en.wikipedia.org/wiki/Artificial_intel...
# 4              https://en.wikipedia.org/wiki/Weak_AI
#
#                                             keywords
# 0  ['intelligent', 'agents', 'agent', 'autonomous...
# 1  ['chatbots', 'apps', 'keywords', 'conversation...
# 2  ['cats', 'cat', 'neurons', 'images', 'biologic...
# 3  ['ai', 'intelligence', 'machines', 'humans', '...
# 4  ['ai', 'narrow', 'weak', 'minds', 'intelligenc...

# %%
df_edge.head()
# Out:
#    source  target
# 0       0      95
# 1       0      69
# 2       0     103
# 3       0      94
# 4       0      99

# %%
# Create placeholders for graph information
labels = df_node['name'].tolist()
color_node = ['rgba(200,200,200,0.05)' for i in range(3*len(labels))]
color_node_original = color_node.copy()
texts_to_show = [None for i in range(len(labels))]
texts_to_show_original = texts_to_show.copy()
size_node = [15 for i in range(len(labels))]
size_node_original = size_node.copy()
color_edge = ['rgba(128,128,128,0.7)' for _ in range(3*len(df_edge))]
color_edge_original = color_edge.copy()

# Create plotting items
# title, annotations, textbox_query, selector, query_answer, g = create_plot_items(df_node,df_edge,labels,color_node,texts_to_show,color_edge)

# %%
# import pickle
# with open(os.path.join(GENERATED_DATA_PATH,'graph.pkl'),'wb') as f:
#     pickle.dump(g,f)

# %%
# Load graph and models
title, annotations, textbox_query, selector, query_answer, g = load_graph()
query_bot = load_models()

# %%
def find_index_edges(nodes_ls):
    edges_idx = []
    for source in nodes_ls:
        for target in nodes_ls:
            filtered = df_edge[((df_edge.source == source) & (df_edge.target == target) ) | ( (df_edge.source == target) & (df_edge.target == source) )]
            if len(filtered)!=0:
                edges_idx.append(filtered.index.values[0])
                
    return edges_idx

# %%
current_selector = selector.value

# Choose the model
def response(change):
    global current_selector
    current_selector = selector.value
    make_query(textbox_query)
    
# On a new query, compute the predictions and color the nodes accordingly
def make_query(user_query):
    global current_selector
    global color_node_original
    global texts_to_show_original
    global size_node_original
    global color_edge_original
    texts_to_show = texts_to_show_original.copy()
    color_node = color_node_original.copy()
    size_node = size_node_original.copy()
    color_edge = color_edge_original.copy()
    
    query = user_query.value
    if query != "":
        preds = query_bot.make_prediction(query, current_selector)
        #preds = {10:1,11:0.8,12:0.6,13:0.4,14:0.3}
        if preds == None:
            html_text = create_text([],df_node)
            query_answer.value = html_text
        else:
            dict_colors = compute_color(preds)
        
            html_text = create_text(list(dict_colors.keys()),df_node)
            query_answer.value = html_text

            for k,v in dict_colors.items():
                size_node[k] = 30
                color_node[k] = v
                texts_to_show[k] = labels[k]
            
            edges_idx = find_index_edges(list(preds.keys()))
            for idx in edges_idx:
                color_edge[3*idx] = 'rgb(255,0,0,1)'
            

        with g.batch_update():
            g.data[1].marker.size = size_node
            g.data[1].marker.color = color_node
            g.data[1].text = texts_to_show
            g.data[0].line.color = color_edge
            
# Open url when clicking on node
def update_point(trace, points, selector):
    if len(points.point_inds) != 0:
        url = g.data[1].customdata[points.point_inds[0]]
        webbrowser.open_new_tab(url)
    
textbox_query.on_submit(make_query)
selector.observe(response, names="value")
g.data[1].on_click(update_point)

with g.batch_update():
    g.data[1].marker.color = color_node_original.copy()
    g.data[1].marker.size = size_node_original.copy()
    g.data[1].text = texts_to_show_original.copy()
    g.data[0].line.color = color_edge_original.copy()
    g.data[0].line.width = 10

# %%
query_bot.node2vec.wv.vocab
# Out:
# {'intelligent computer-assisted language instruction': <gensim.models.keyedvectors.Vocab at 0x7efdd0326c88>,
#  'foreign language reading aid': <gensim.models.keyedvectors.Vocab at 0x7efdd0349e10>,
#  'social media language learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1a90>,
#  'language immersion': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1b00>,
#  'babbel': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1b70>,
#  'tandem language learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1ba8>,
#  'online learning community': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1be0>,
#  'community language learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1c18>,
#  'the alpheios project': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1c50>,
#  'language education': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1c88>,
#  'foreign language writing aid': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1cc0>,
#  'native-language identification': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1cf8>,
#  'computer-assisted language learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1d30>,
#  'crosslinguistic influence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1d68>,
#  'natural language processing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1da0>,
#  'language transfer': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1dd8>,
#  'natural language user interface': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1e10>,
#  'state–action–reward–state–action': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1e48>,
#  'reinforcement learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1e80>,
#  'multi-agent system': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1eb8>,
#  'human-based genetic algorithm': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1ef0>,
#  'swarm robotics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1f28>,
#  'platbox project': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1f60>,
#  'knowledge query and manipulation language': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1f98>,
#  'artificial life': <gensim.models.keyedvectors.Vocab at 0x7efdcd9e1fd0>,
#  'cybernetics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8048>,
#  'synergetics (haken)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8080>,
#  'variety (cybernetics)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f80b8>,
#  'autonomous agency theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f80f0>,
#  'chaos theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8128>,
#  'radial basis function network': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8160>,
#  'in situ adaptive tabulation': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8198>,
#  'support vector machine': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f81d0>,
#  'cerebellar model articulation controller': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8208>,
#  'artificial neural network': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8240>,
#  'time delay neural network': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8278>,
#  'recurrent neural networks': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f82b0>,
#  'hierarchical temporal memory': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f82e8>,
#  'multiple trace theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8320>,
#  'neural turing machine': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8358>,
#  'neocognitron': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8390>,
#  'predictive inference': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f83c8>,
#  'predictive analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8400>,
#  'exploratory data analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8438>,
#  'descriptive statistics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8470>,
#  'data dredging': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f84a8>,
#  'configural frequency analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f84e0>,
#  'data analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8518>,
#  'data visualization': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8550>,
#  'interaction techniques': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8588>,
#  'information visualization': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f85c0>,
#  'geovisualization': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f85f8>,
#  'data presentation architecture': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8630>,
#  'information architecture': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8668>,
#  'statistical graphics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f86a0>,
#  'analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f86d8>,
#  'prediction': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8710>,
#  'news analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8748>,
#  'complex event processing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8780>,
#  'semantic analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f87b8>,
#  'analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f87f0>,
#  'business analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8828>,
#  'social analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8860>,
#  'statistics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8898>,
#  'applications architecture': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f88d0>,
#  'wayfinding': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8908>,
#  'tree testing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8940>,
#  'content strategy': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8978>,
#  'chief experience officer': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f89b0>,
#  'information design': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f89e8>,
#  'visual literacy': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8a20>,
#  'infographic': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8a58>,
#  'graphic image development': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8a90>,
#  'argument map': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8ac8>,
#  'maestro concept': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8b00>,
#  'technical illustration': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8b38>,
#  'family tree': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8b70>,
#  'graphic organizer': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8ba8>,
#  'chart': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8c18>,
#  'text analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8c50>,
#  'visual analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8c88>,
#  'critical thinking': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8cc0>,
#  'abductive reasoning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8cf8>,
#  'statistical model': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8d30>,
#  'semantic search': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8d68>,
#  'selection-based search': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8da0>,
#  'noisy text': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8dd8>,
#  'semantic query': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8e10>,
#  'natural user interface': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8e48>,
#  'question answering': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8e80>,
#  'language and communication technologies': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8eb8>,
#  'natural language programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8ef0>,
#  'domain-specific language': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8f28>,
#  'very high-level programming language': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8f60>,
#  'context-free language': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8f98>,
#  'transcript (programming language)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9f8fd0>,
#  'flow-matic': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe048>,
#  'cobol': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe0b8>,
#  'knowledge representation': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe0f0>,
#  'robert e. horn': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe128>,
#  'lawrence j. rosenblum': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe160>,
#  'scientific visualization': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe198>,
#  'tomviz': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe208>,
#  'mathematical visualization': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe240>,
#  'visad': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe2b0>,
#  'big data': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe2e8>,
#  'data science': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe320>,
#  'business intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe358>,
#  'enterprise planning systems': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe390>,
#  'management information system': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe3c8>,
#  'mobile business intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe400>,
#  'business intelligence software': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe438>,
#  'accounting intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe470>,
#  'business activity monitoring': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe4a8>,
#  'data mining': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe4e0>,
#  'information retrieval': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe518>,
#  'nearest centroid classifier': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe550>,
#  'multimedia information retrieval': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe588>,
#  'amira (software)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe5c0>,
#  'paraview': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe5f8>,
#  'interaction design': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe630>,
#  'web analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe668>,
#  'unstructured data': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe6a0>,
#  'wavelet': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe710>,
#  'system identification': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe748>,
#  'digital signal processing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe780>,
#  'datacopia': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe7b8>,
#  'orange (software)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe7f0>,
#  'news illustrated': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe828>,
#  'graphic design': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe860>,
#  'visualization (graphic)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe898>,
#  'decision engineering': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe8d0>,
#  'process mining': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe908>,
#  'sales intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe940>,
#  'business process discovery': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe978>,
#  'customer dynamics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe9b0>,
#  'business intelligence 2.0': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fe9e8>,
#  'software analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fea20>,
#  'architectural analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fea58>,
#  'smart grid': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fea90>,
#  'operations research': <gensim.models.keyedvectors.Vocab at 0x7efdcd9feac8>,
#  'business analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9feb00>,
#  'enterprise information security architecture': <gensim.models.keyedvectors.Vocab at 0x7efdcd9feb38>,
#  'site map': <gensim.models.keyedvectors.Vocab at 0x7efdcd9feb70>,
#  'ecological interface design': <gensim.models.keyedvectors.Vocab at 0x7efdcd9feba8>,
#  'social information architecture': <gensim.models.keyedvectors.Vocab at 0x7efdcd9febe0>,
#  'desensitization (psychology)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fec18>,
#  'habituation': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fec50>,
#  'tachyphylaxis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fec88>,
#  'konrad lorenz': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fecc0>,
#  'adaptive system': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fecf8>,
#  'aplysia': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fed68>,
#  'behind the mirror: a search for a natural history of human knowledge': <gensim.models.keyedvectors.Vocab at 0x7efdcd9feda0>,
#  'hierarchical rbf': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fedd8>,
#  'gene expression programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fee10>,
#  'evolutionary algorithms': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fee48>,
#  'decision trees': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fee80>,
#  'genetic algorithms': <gensim.models.keyedvectors.Vocab at 0x7efdcd9feeb8>,
#  'connectomics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9feef0>,
#  'human connectome project': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fef28>,
#  'in-memory processing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fef60>,
#  'balanced scorecard': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fef98>,
#  'performance management': <gensim.models.keyedvectors.Vocab at 0x7efdcd9fefd0>,
#  'marketing strategy': <gensim.models.keyedvectors.Vocab at 0x7efdcda07048>,
#  'key performance indicators': <gensim.models.keyedvectors.Vocab at 0x7efdcda07080>,
#  'strategy map': <gensim.models.keyedvectors.Vocab at 0x7efdcda070b8>,
#  'machine learning': <gensim.models.keyedvectors.Vocab at 0x7efdcda070f0>,
#  'weak ai': <gensim.models.keyedvectors.Vocab at 0x7efdcda07160>,
#  'artificial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcda07198>,
#  'citizen science': <gensim.models.keyedvectors.Vocab at 0x7efdcda071d0>,
#  'public participation': <gensim.models.keyedvectors.Vocab at 0x7efdcda07208>,
#  'genealogy': <gensim.models.keyedvectors.Vocab at 0x7efdcda07240>,
#  'participation (decision making)': <gensim.models.keyedvectors.Vocab at 0x7efdcda07278>,
#  'popular science': <gensim.models.keyedvectors.Vocab at 0x7efdcda072b0>,
#  'independent scholar': <gensim.models.keyedvectors.Vocab at 0x7efdcda072e8>,
#  'glossary of language teaching terms and ideas': <gensim.models.keyedvectors.Vocab at 0x7efdcda07320>,
#  'second language acquisition': <gensim.models.keyedvectors.Vocab at 0x7efdcda07358>,
#  'virtual world language learning': <gensim.models.keyedvectors.Vocab at 0x7efdcda07390>,
#  'language acquisition': <gensim.models.keyedvectors.Vocab at 0x7efdcda073c8>,
#  'smigin': <gensim.models.keyedvectors.Vocab at 0x7efdcda07438>,
#  'transformer (machine learning model)': <gensim.models.keyedvectors.Vocab at 0x7efdcda07470>,
#  'deep linguistic processing': <gensim.models.keyedvectors.Vocab at 0x7efdcda074a8>,
#  'tree-adjoining grammar': <gensim.models.keyedvectors.Vocab at 0x7efdcda074e0>,
#  'head-driven phrase structure grammar': <gensim.models.keyedvectors.Vocab at 0x7efdcda07518>,
#  'combinatory categorial grammar': <gensim.models.keyedvectors.Vocab at 0x7efdcda07550>,
#  'lexical functional grammar': <gensim.models.keyedvectors.Vocab at 0x7efdcda07588>,
#  'social information seeking': <gensim.models.keyedvectors.Vocab at 0x7efdcda075c0>,
#  'collaborative information seeking': <gensim.models.keyedvectors.Vocab at 0x7efdcda075f8>,
#  'relevance feedback': <gensim.models.keyedvectors.Vocab at 0x7efdcda07630>,
#  'adversarial information retrieval': <gensim.models.keyedvectors.Vocab at 0x7efdcda07668>,
#  'query expansion': <gensim.models.keyedvectors.Vocab at 0x7efdcda076a0>,
#  'search engine indexing': <gensim.models.keyedvectors.Vocab at 0x7efdcda076d8>,
#  '1 the road': <gensim.models.keyedvectors.Vocab at 0x7efdcda07710>,
#  'distributional semantics': <gensim.models.keyedvectors.Vocab at 0x7efdcda07748>,
#  'statistical semantics': <gensim.models.keyedvectors.Vocab at 0x7efdcda07780>,
#  'magnus sahlgren': <gensim.models.keyedvectors.Vocab at 0x7efdcda077b8>,
#  'zellig harris': <gensim.models.keyedvectors.Vocab at 0x7efdcda077f0>,
#  'latent semantic indexing': <gensim.models.keyedvectors.Vocab at 0x7efdcda07828>,
#  'word vector': <gensim.models.keyedvectors.Vocab at 0x7efdcda07860>,
#  'latent semantic mapping': <gensim.models.keyedvectors.Vocab at 0x7efdcda07898>,
#  'coh-metrix': <gensim.models.keyedvectors.Vocab at 0x7efdcda078d0>,
#  'information extraction': <gensim.models.keyedvectors.Vocab at 0x7efdcda07908>,
#  'automated essay scoring': <gensim.models.keyedvectors.Vocab at 0x7efdcda07940>,
#  'inform 7': <gensim.models.keyedvectors.Vocab at 0x7efdcda07978>,
#  'xtalk': <gensim.models.keyedvectors.Vocab at 0x7efdcda079e8>,
#  'open mind common sense': <gensim.models.keyedvectors.Vocab at 0x7efdcda07a20>,
#  'cognitive architecture': <gensim.models.keyedvectors.Vocab at 0x7efdcda07a58>,
#  'jack intelligent agents': <gensim.models.keyedvectors.Vocab at 0x7efdcda07a90>,
#  'intelligent agent': <gensim.models.keyedvectors.Vocab at 0x7efdcda07ac8>,
#  'interactive online characters': <gensim.models.keyedvectors.Vocab at 0x7efdcda07b00>,
#  'chatbot': <gensim.models.keyedvectors.Vocab at 0x7efdcda07b70>,
#  'software agent': <gensim.models.keyedvectors.Vocab at 0x7efdcda07ba8>,
#  'social simulation': <gensim.models.keyedvectors.Vocab at 0x7efdcda07be0>,
#  'microbial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcda07c18>,
#  'learning classifier system': <gensim.models.keyedvectors.Vocab at 0x7efdcda07c50>,
#  'federated search': <gensim.models.keyedvectors.Vocab at 0x7efdcda07c88>,
#  'z39.50': <gensim.models.keyedvectors.Vocab at 0x7efdcda07cf8>,
#  'search aggregator': <gensim.models.keyedvectors.Vocab at 0x7efdcda07d30>,
#  'computer science': <gensim.models.keyedvectors.Vocab at 0x7efdcda07d68>,
#  'digital revolution': <gensim.models.keyedvectors.Vocab at 0x7efdcda07da0>,
#  'software engineering': <gensim.models.keyedvectors.Vocab at 0x7efdcda07dd8>,
#  'algorithmic trading': <gensim.models.keyedvectors.Vocab at 0x7efdcda07e10>,
#  'learning analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcda07e48>,
#  'computational linguistics': <gensim.models.keyedvectors.Vocab at 0x7efdcda07e80>,
#  'truecasing': <gensim.models.keyedvectors.Vocab at 0x7efdcda07eb8>,
#  'eugene goostman': <gensim.models.keyedvectors.Vocab at 0x7efdcda07ef0>,
#  'internet bot': <gensim.models.keyedvectors.Vocab at 0x7efdcda07f28>,
#  'votebots': <gensim.models.keyedvectors.Vocab at 0x7efdcda07f60>,
#  'social bot': <gensim.models.keyedvectors.Vocab at 0x7efdcda07f98>,
#  'search engine manipulation effect': <gensim.models.keyedvectors.Vocab at 0x7efdcda07fd0>,
#  'whispering campaign': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e048>,
#  'twitter bomb': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e080>,
#  'messaging spam': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e0b8>,
#  'jjaibot': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e128>,
#  'technoself studies': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e160>,
#  "on the internet, nobody knows you're a dog": <gensim.models.keyedvectors.Vocab at 0x7efdcd98e198>,
#  'fake news website': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e1d0>,
#  'hypertalk': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e208>,
#  'joss': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e278>,
#  'software ag': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e2b0>,
#  'speech processing': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e2e8>,
#  'speech coding': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e320>,
#  'biomedical text mining': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e358>,
#  'susan dumais': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e390>,
#  'word2vec': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e3c8>,
#  'normalized compression distance': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e400>,
#  'vector space model': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e438>,
#  'feature learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e470>,
#  'autoencoder': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e4a8>,
#  'language model': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e4e0>,
#  'thought vector': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e518>,
#  'basic income around the world': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e550>,
#  'universal basic income': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e588>,
#  'cash transfers': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e5c0>,
#  "citizen's dividend": <gensim.models.keyedvectors.Vocab at 0x7efdcd98e5f8>,
#  'economic, social and cultural rights': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e630>,
#  'universal credit': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e668>,
#  'redistribution of income and wealth': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e6a0>,
#  'equality of outcome': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e6d8>,
#  'minimum wage': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e710>,
#  'automation and the future of jobs': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e748>,
#  'post-scarcity economy': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e780>,
#  'universal basic services': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e7b8>,
#  'speenhamland system': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e7f0>,
#  'involuntary unemployment': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e828>,
#  'software maintenance': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e860>,
#  'software visualization': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e898>,
#  'sourcetrail': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e8d0>,
#  'software map': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e908>,
#  'sotoarc': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e978>,
#  'software archaeology': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e9b0>,
#  'sonargraph': <gensim.models.keyedvectors.Vocab at 0x7efdcd98e9e8>,
#  'getaviz': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ea58>,
#  'ndepend': <gensim.models.keyedvectors.Vocab at 0x7efdcd98eac8>,
#  'softagram': <gensim.models.keyedvectors.Vocab at 0x7efdcd98eb00>,
#  'imagix 4d': <gensim.models.keyedvectors.Vocab at 0x7efdcd98eb38>,
#  'application discovery and understanding': <gensim.models.keyedvectors.Vocab at 0x7efdcd98eb70>,
#  'infographics': <gensim.models.keyedvectors.Vocab at 0x7efdcd98eba8>,
#  'computer facial animation': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ebe0>,
#  'conversational user interface': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ec18>,
#  'wizard (software)': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ec50>,
#  'knowledge navigator': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ec88>,
#  'cognitive science': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ecc0>,
#  'blue brain project': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ecf8>,
#  'simulated reality': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ed30>,
#  'subjective idealism': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ed68>,
#  'journal of artificial societies and social simulation': <gensim.models.keyedvectors.Vocab at 0x7efdcd98eda0>,
#  'cliodynamics': <gensim.models.keyedvectors.Vocab at 0x7efdcd98edd8>,
#  'agent-based social simulation': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ee10>,
#  'multiple-agent system': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ee48>,
#  'artificial society': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ee80>,
#  'artificial reality': <gensim.models.keyedvectors.Vocab at 0x7efdcd98eeb8>,
#  'agent-based computational economics': <gensim.models.keyedvectors.Vocab at 0x7efdcd98eef0>,
#  'multi-agent planning': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ef28>,
#  'game theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ef60>,
#  'autonomous agent': <gensim.models.keyedvectors.Vocab at 0x7efdcd98ef98>,
#  'agent-based model': <gensim.models.keyedvectors.Vocab at 0x7efdcd98efd0>,
#  'complex adaptive system': <gensim.models.keyedvectors.Vocab at 0x7efdcd997048>,
#  'comparison of agent-based modeling software': <gensim.models.keyedvectors.Vocab at 0x7efdcd997080>,
#  'social complexity': <gensim.models.keyedvectors.Vocab at 0x7efdcd9970b8>,
#  'emergence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9970f0>,
#  'emergent algorithm': <gensim.models.keyedvectors.Vocab at 0x7efdcd997128>,
#  'evolutionary computation': <gensim.models.keyedvectors.Vocab at 0x7efdcd997160>,
#  'neuroevolution': <gensim.models.keyedvectors.Vocab at 0x7efdcd997198>,
#  'spectrum-diverse unified neuroevolution architecture': <gensim.models.keyedvectors.Vocab at 0x7efdcd9971d0>,
#  'automated machine learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd997208>,
#  'model selection': <gensim.models.keyedvectors.Vocab at 0x7efdcd997240>,
#  'neuroscience': <gensim.models.keyedvectors.Vocab at 0x7efdcd997278>,
#  'budapest reference connectome': <gensim.models.keyedvectors.Vocab at 0x7efdcd9972b0>,
#  'beam robotics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9972e8>,
#  'turtle (robot)': <gensim.models.keyedvectors.Vocab at 0x7efdcd997320>,
#  'phototrope': <gensim.models.keyedvectors.Vocab at 0x7efdcd997358>,
#  'william grey walter': <gensim.models.keyedvectors.Vocab at 0x7efdcd997390>,
#  'emergent behaviour': <gensim.models.keyedvectors.Vocab at 0x7efdcd9973c8>,
#  'fuzzy concept': <gensim.models.keyedvectors.Vocab at 0x7efdcd997400>,
#  'fuzzy logic': <gensim.models.keyedvectors.Vocab at 0x7efdcd997438>,
#  'neuro-fuzzy': <gensim.models.keyedvectors.Vocab at 0x7efdcd997470>,
#  'false dilemma': <gensim.models.keyedvectors.Vocab at 0x7efdcd9974a8>,
#  'type-2 fuzzy sets and systems': <gensim.models.keyedvectors.Vocab at 0x7efdcd9974e0>,
#  'adaptive neuro fuzzy inference system': <gensim.models.keyedvectors.Vocab at 0x7efdcd997518>,
#  'ieee computational intelligence society': <gensim.models.keyedvectors.Vocab at 0x7efdcd997550>,
#  'swarm intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd997588>,
#  'nick bostrom': <gensim.models.keyedvectors.Vocab at 0x7efdcd9975c0>,
#  'language exchange': <gensim.models.keyedvectors.Vocab at 0x7efdcd9975f8>,
#  'business process reengineering': <gensim.models.keyedvectors.Vocab at 0x7efdcd997630>,
#  'business process automation': <gensim.models.keyedvectors.Vocab at 0x7efdcd997668>,
#  'real-time enterprise': <gensim.models.keyedvectors.Vocab at 0x7efdcd9976a0>,
#  'business rules engine': <gensim.models.keyedvectors.Vocab at 0x7efdcd9976d8>,
#  'job scheduler': <gensim.models.keyedvectors.Vocab at 0x7efdcd997710>,
#  'business process model and notation': <gensim.models.keyedvectors.Vocab at 0x7efdcd997748>,
#  'business-driven development': <gensim.models.keyedvectors.Vocab at 0x7efdcd997780>,
#  'business process execution language': <gensim.models.keyedvectors.Vocab at 0x7efdcd9977b8>,
#  'runbook': <gensim.models.keyedvectors.Vocab at 0x7efdcd997828>,
#  'personality computing': <gensim.models.keyedvectors.Vocab at 0x7efdcd997860>,
#  'artificial brain': <gensim.models.keyedvectors.Vocab at 0x7efdcd997898>,
#  'spiking neural network': <gensim.models.keyedvectors.Vocab at 0x7efdcd9978d0>,
#  'systems neuroscience': <gensim.models.keyedvectors.Vocab at 0x7efdcd997908>,
#  'models of neural computation': <gensim.models.keyedvectors.Vocab at 0x7efdcd997940>,
#  'neural correlate': <gensim.models.keyedvectors.Vocab at 0x7efdcd997978>,
#  'neuroinformatics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9979b0>,
#  'motion perception': <gensim.models.keyedvectors.Vocab at 0x7efdcd9979e8>,
#  'anki (software)': <gensim.models.keyedvectors.Vocab at 0x7efdcd997a20>,
#  'duolingo': <gensim.models.keyedvectors.Vocab at 0x7efdcd997a58>,
#  'language mooc': <gensim.models.keyedvectors.Vocab at 0x7efdcd997a90>,
#  'roy ascott': <gensim.models.keyedvectors.Vocab at 0x7efdcd997ac8>,
#  'data art': <gensim.models.keyedvectors.Vocab at 0x7efdcd997b00>,
#  'big data ethics': <gensim.models.keyedvectors.Vocab at 0x7efdcd997b38>,
#  'multilinear subspace learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd997b70>,
#  'experiments in art and technology': <gensim.models.keyedvectors.Vocab at 0x7efdcd997ba8>,
#  'digital art': <gensim.models.keyedvectors.Vocab at 0x7efdcd997be0>,
#  'algorithmic art': <gensim.models.keyedvectors.Vocab at 0x7efdcd997c18>,
#  'systems art': <gensim.models.keyedvectors.Vocab at 0x7efdcd997c50>,
#  'systems thinking': <gensim.models.keyedvectors.Vocab at 0x7efdcd997c88>,
#  'computer art': <gensim.models.keyedvectors.Vocab at 0x7efdcd997cc0>,
#  'climate spiral': <gensim.models.keyedvectors.Vocab at 0x7efdcd997cf8>,
#  'the tempestry project': <gensim.models.keyedvectors.Vocab at 0x7efdcd997d30>,
#  'tradigital art': <gensim.models.keyedvectors.Vocab at 0x7efdcd997d68>,
#  'warming stripes': <gensim.models.keyedvectors.Vocab at 0x7efdcd997da0>,
#  'glossary of artificial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd997dd8>,
#  'genetic programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd997e10>,
#  'grammatical evolution': <gensim.models.keyedvectors.Vocab at 0x7efdcd997e48>,
#  'multi expression programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd997e80>,
#  'document-term matrix': <gensim.models.keyedvectors.Vocab at 0x7efdcd997eb8>,
#  'deep learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd997ef0>,
#  'intelligent personal assistant': <gensim.models.keyedvectors.Vocab at 0x7efdcd997f28>,
#  'history of artificial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd997f60>,
#  'expert system': <gensim.models.keyedvectors.Vocab at 0x7efdcd997f98>,
#  'fuzzy electronics': <gensim.models.keyedvectors.Vocab at 0x7efdcd997fd0>,
#  'vector logic': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1048>,
#  'web engineering': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1080>,
#  'semantic web': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a10b8>,
#  'semantic integration': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a10f0>,
#  'semantic computing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1128>,
#  'nextbio': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1198>,
#  'computational semantics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a11d0>,
#  'semantic technology': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1208>,
#  'semantic sensor web': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1240>,
#  'hyperdata': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1278>,
#  'semantically-interlinked online communities': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a12b0>,
#  'web resource': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a12e8>,
#  'web science': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1320>,
#  'dbpedia': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1390>,
#  'social semantic web': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a13c8>,
#  'entity-attribute-value model': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1400>,
#  'welfare capitalism': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1438>,
#  'old age security': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1470>,
#  'global basic income': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a14a8>,
#  'working time': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a14e0>,
#  'mincome': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1550>,
#  'unemployment benefits': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1588>,
#  'the triple revolution': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a15c0>,
#  'quatinga velho': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a15f8>,
#  'refusal of work': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1630>,
#  'right to adequate standard of living': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1668>,
#  'parallel distributed processing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a16a0>,
#  'fasttext': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a16d8>,
#  'hinrich schütze': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1710>,
#  'declarative programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1748>,
#  'goal agent programming language': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1780>,
#  'biologically inspired cognitive architectures': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a17b8>,
#  'unified theory of cognition': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a17f0>,
#  'tensor product network': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1828>,
#  'odds algorithm': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1860>,
#  'structured data analysis (statistics)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1898>,
#  "anscombe's quartet": <gensim.models.keyedvectors.Vocab at 0x7efdcd9a18d0>,
#  'very large database': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1908>,
#  'test method': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1940>,
#  'nearest neighbor search': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1978>,
#  'data curation': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a19b0>,
#  'big data maturity model': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a19e8>,
#  'timeline': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1a20>,
#  'a picture is worth a thousand words': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1a58>,
#  'plain language': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1a90>,
#  'spreadmart': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1ac8>,
#  'viability study': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1b00>,
#  'revenue shortfall': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1b38>,
#  'requirements analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1b70>,
#  'cost overrun': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1ba8>,
#  'international institute of business analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1be0>,
#  'data blending': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1c18>,
#  'data profiling': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1c50>,
#  'database normalization': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1c88>,
#  'analysis paralysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1cc0>,
#  'isotype (picture language)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1cf8>,
#  'siam journal on scientific computing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1d30>,
#  'master data management': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1d68>,
#  'data quality': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1da0>,
#  'flocking (behavior)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1dd8>,
#  'dynamic network analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1e10>,
#  'augmented reality': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1e48>,
#  'virtual world': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1e80>,
#  'computational sociology': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1eb8>,
#  'early case assessment': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1ef0>,
#  'dimension reduction': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1f28>,
#  'data governance': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1f60>,
#  'instructional design': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1f98>,
#  'interactive systems engineering': <gensim.models.keyedvectors.Vocab at 0x7efdcd9a1fd0>,
#  'subject indexing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa048>,
#  'information retrieval facility': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa080>,
#  'relevance (information retrieval)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa0b8>,
#  'knowledge visualization': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa0f0>,
#  'cartography': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa128>,
#  'speech analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa160>,
#  'social spam': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa198>,
#  'applications of artificial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa1d0>,
#  'applications of deep learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa208>,
#  'progress in artificial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa240>,
#  'actuarial science': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa278>,
#  'quantum machine learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa2b0>,
#  'quantum neural network': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa2e8>,
#  'quantum algorithm for linear systems of equations': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa320>,
#  'adaline': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa390>,
#  'wired intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa3c8>,
#  'typography': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa400>,
#  'charts': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa470>,
#  'user experience design': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa4a8>,
#  'controlled vocabulary': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa4e0>,
#  'compound term processing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa518>,
#  'text simplification': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa550>,
#  'semantic compression': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa588>,
#  'text normalization': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa5c0>,
#  'simplified technical english': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa5f8>,
#  'lexical simplification': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa630>,
#  'automated paraphrasing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa668>,
#  'cleartalk': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa6a0>,
#  'applescript': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa6d8>,
#  'automatic programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa710>,
#  'end-user programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa748>,
#  'reification (linguistics)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa780>,
#  'spambot': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa7f0>,
#  'agent architecture': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa828>,
#  'blackboard system': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa860>,
#  'a.i. rising': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa898>,
#  'artificial intelligence arms race': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa8d0>,
#  'unmanned combat aerial vehicle': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa908>,
#  'malleable intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa940>,
#  'informatics (academic field)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa978>,
#  'cognitive biology': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa9b0>,
#  'strategic management': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aa9e8>,
#  'strategic control': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aaa20>,
#  'visual journalism': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aaa58>,
#  'video journalism': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aaa90>,
#  'broadcast journalism': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aaac8>,
#  'media psychology': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aab00>,
#  'faceted classification': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aab38>,
#  'informatics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aab70>,
#  'transgenerational design': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aaba8>,
#  'data acquisition': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aabe0>,
#  'multiway data analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aac18>,
#  'explanation-based learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aac50>,
#  'one-shot learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aac88>,
#  'connectionism': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aacc0>,
#  'biologically inspired computing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aacf8>,
#  'fuzzy architectural spatial analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aad30>,
#  'fuzzyclips': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aad68>,
#  'high performance fuzzy computing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aada0>,
#  'interval finite element': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aadd8>,
#  'fuzzy subalgebra': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aae10>,
#  'sorites paradox': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aae48>,
#  'fuzzy control language': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aae80>,
#  'social network analysis software': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aaeb8>,
#  'john stasko': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aaef0>,
#  'jim thomas (visualization)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aaf28>,
#  'theresa-marie rhyne': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aaf60>,
#  'cecilia r. aragon': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aaf98>,
#  'google analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9aafd0>,
#  'kinetic user interface': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4048>,
#  'hardware interface design': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4080>,
#  'service design': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b40b8>,
#  'interaction design pattern': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b40f0>,
#  'sonic interaction design': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4128>,
#  'human interface guidelines': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4160>,
#  'applications of machine learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4198>,
#  'comparison of deep learning software': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b41d0>,
#  'neural network software': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4208>,
#  'physical neural network': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4240>,
#  'patent visualisation': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4278>,
#  'dashboards (management information systems)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b42b0>,
#  'censoring (statistics)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b42e8>,
#  'computer-assisted translation': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4320>,
#  'computer-assisted reviewing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4358>,
#  'grammar induction': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4390>,
#  'artificial intelligence in fiction': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b43c8>,
#  'collostructional analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4400>,
#  'semantic relatedness': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4438>,
#  'knowledge extraction': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4470>,
#  'enterprise search': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b44a8>,
#  'named entity recognition': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b44e0>,
#  'open information extraction': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4518>,
#  'data extraction': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4550>,
#  'temporal information retrieval': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4588>,
#  'tf-idf': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b45f8>,
#  'european summer school in information retrieval': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4630>,
#  'kinetic exchange models of markets': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4668>,
#  'swarming behaviour': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b46a0>,
#  'ubot studio': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b46d8>,
#  'irc bot': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4748>,
#  'marketing and artificial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4780>,
#  'language technology': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b47b8>,
#  'controlled natural language': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b47f0>,
#  'structured english': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4828>,
#  'genetic algorithm': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4860>,
#  'neural gas': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4898>,
#  'self-organizing map': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b48d0>,
#  'learning vector quantization': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4908>,
#  'google brain': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4940>,
#  'theory of knowledge': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4978>,
#  'omega point (tipler)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b49b0>,
#  'margolus–levitin theorem': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b49e8>,
#  'allegory of the cave': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4a20>,
#  'rené descartes': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4a58>,
#  'embodied agent': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4a90>,
#  'player character': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4ac8>,
#  'internet relay chat bot': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4b00>,
#  'whole brain emulation': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4b38>,
#  'image schema': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4b70>,
#  'liquid state machine': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4ba8>,
#  'hybrid kohonen som': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4be0>,
#  'neural networks': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4c18>,
#  'artificial consciousness': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4c50>,
#  'on intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4c88>,
#  'hierarchical hidden markov model': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4cc0>,
#  'bayesian networks': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4cf8>,
#  'bionics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4d68>,
#  'linear genetic programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4da0>,
#  'inductive programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4dd8>,
#  'adaptive resonance theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4e10>,
#  'systolic array': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4e48>,
#  'iwarp': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4eb8>,
#  'misd': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4f28>,
#  'warp (systolic array)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4f60>,
#  'biological cybernetics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4f98>,
#  'neural coding': <gensim.models.keyedvectors.Vocab at 0x7efdcd9b4fd0>,
#  'neural decoding': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd048>,
#  'cognitive psychology': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd080>,
#  'human–computer interaction': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd0b8>,
#  'indiana archives of cognitive science': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd0f0>,
#  'affective science': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd128>,
#  'quantum cognition': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd160>,
#  'home network': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd198>,
#  'virtual reality': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd1d0>,
#  'sparse distributed memory': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd208>,
#  'binding problem': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd240>,
#  'neural oscillation': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd278>,
#  'convolutional neural network': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd2b0>,
#  'vision processing unit': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd2e8>,
#  'scale-invariant feature transform': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd320>,
#  'belief revision': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd358>,
#  'belief propagation': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd390>,
#  'memory-prediction framework': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd3c8>,
#  'artificial general intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd400>,
#  'natural-language processing': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd438>,
#  'convolution': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd470>,
#  'viable systems approach': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd4a8>,
#  'decision theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd4e0>,
#  'cyborgs': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd550>,
#  'semiotics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd588>,
#  'principia cybernetica': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd5c0>,
#  'management science': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd5f8>,
#  'intelligence amplification': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd630>,
#  'ratio club': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd668>,
#  'brain–computer interface': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd6a0>,
#  'gaia hypothesis': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd6d8>,
#  'behaviorism': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd710>,
#  'feature integration theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd748>,
#  'associationism': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd780>,
#  'catastrophic interference': <gensim.models.keyedvectors.Vocab at 0x7efdcd9bd7b8>,
# ...
#  'codi': <gensim.models.keyedvectors.Vocab at 0x7efdcd9594e0>,
#  'integrated development environment': <gensim.models.keyedvectors.Vocab at 0x7efdcd959518>,
#  'ai accelerator': <gensim.models.keyedvectors.Vocab at 0x7efdcd959550>,
#  'protoscience': <gensim.models.keyedvectors.Vocab at 0x7efdcd959588>,
#  'human factors and ergonomics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9595c0>,
#  'daniel a. keim': <gensim.models.keyedvectors.Vocab at 0x7efdcd9595f8>,
#  'argument': <gensim.models.keyedvectors.Vocab at 0x7efdcd959630>,
#  'argumentation theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd959668>,
#  'sign relation': <gensim.models.keyedvectors.Vocab at 0x7efdcd9596a0>,
#  'duck test': <gensim.models.keyedvectors.Vocab at 0x7efdcd9596d8>,
#  'economy of cuba': <gensim.models.keyedvectors.Vocab at 0x7efdcd959710>,
#  'philosophy of artificial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd959748>,
#  'web indexing': <gensim.models.keyedvectors.Vocab at 0x7efdcd959780>,
#  'content management': <gensim.models.keyedvectors.Vocab at 0x7efdcd9597b8>,
#  'climate change art': <gensim.models.keyedvectors.Vocab at 0x7efdcd9597f0>,
#  'dataplot': <gensim.models.keyedvectors.Vocab at 0x7efdcd959828>,
#  'baudline': <gensim.models.keyedvectors.Vocab at 0x7efdcd959860>,
#  'acm transactions on graphics': <gensim.models.keyedvectors.Vocab at 0x7efdcd959898>,
#  'ieee transactions on visualization and computer graphics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9598d0>,
#  'tensor glyph': <gensim.models.keyedvectors.Vocab at 0x7efdcd959908>,
#  'inductive probability': <gensim.models.keyedvectors.Vocab at 0x7efdcd959940>,
#  'maximum likelihood': <gensim.models.keyedvectors.Vocab at 0x7efdcd959978>,
#  'charles sanders peirce bibliography': <gensim.models.keyedvectors.Vocab at 0x7efdcd9599b0>,
#  'attribution (psychology)': <gensim.models.keyedvectors.Vocab at 0x7efdcd9599e8>,
#  'logical reasoning': <gensim.models.keyedvectors.Vocab at 0x7efdcd959a20>,
#  'k-line (artificial intelligence)': <gensim.models.keyedvectors.Vocab at 0x7efdcd959a58>,
#  'i know it when i see it': <gensim.models.keyedvectors.Vocab at 0x7efdcd959a90>,
#  'similarity heuristic': <gensim.models.keyedvectors.Vocab at 0x7efdcd959ac8>,
#  'pattern matching': <gensim.models.keyedvectors.Vocab at 0x7efdcd959b00>,
#  'scientific instrument': <gensim.models.keyedvectors.Vocab at 0x7efdcd959b38>,
#  'neural correlates of consciousness': <gensim.models.keyedvectors.Vocab at 0x7efdcd959b70>,
#  'artificial intelligence marketing': <gensim.models.keyedvectors.Vocab at 0x7efdcd959ba8>,
#  'business process management': <gensim.models.keyedvectors.Vocab at 0x7efdcd959be0>,
#  'test and learn': <gensim.models.keyedvectors.Vocab at 0x7efdcd959c18>,
#  'operational reporting': <gensim.models.keyedvectors.Vocab at 0x7efdcd959c50>,
#  'decision-making': <gensim.models.keyedvectors.Vocab at 0x7efdcd959c88>,
#  'plato': <gensim.models.keyedvectors.Vocab at 0x7efdcd959cf8>,
#  'evolutionary algorithm': <gensim.models.keyedvectors.Vocab at 0x7efdcd959d30>,
#  'instantaneously trained neural networks': <gensim.models.keyedvectors.Vocab at 0x7efdcd959d68>,
#  'content addressable parallel processor': <gensim.models.keyedvectors.Vocab at 0x7efdcd959da0>,
#  'social safety net': <gensim.models.keyedvectors.Vocab at 0x7efdcd959dd8>,
#  'living wage': <gensim.models.keyedvectors.Vocab at 0x7efdcd959e10>,
#  'boids': <gensim.models.keyedvectors.Vocab at 0x7efdcd959e80>,
#  'conceptual space': <gensim.models.keyedvectors.Vocab at 0x7efdcd959eb8>,
#  'bayesian approaches to brain function': <gensim.models.keyedvectors.Vocab at 0x7efdcd959ef0>,
#  'casuistry': <gensim.models.keyedvectors.Vocab at 0x7efdcd959f28>,
#  'model-based reasoning': <gensim.models.keyedvectors.Vocab at 0x7efdcd959f60>,
#  'cognitive model': <gensim.models.keyedvectors.Vocab at 0x7efdcd959f98>,
#  'behavioral modeling language': <gensim.models.keyedvectors.Vocab at 0x7efdcd959fd0>,
#  'behavioral modeling in hydrology': <gensim.models.keyedvectors.Vocab at 0x7efdcd962048>,
#  'behavioral modeling': <gensim.models.keyedvectors.Vocab at 0x7efdcd962080>,
#  'bsc swot': <gensim.models.keyedvectors.Vocab at 0x7efdcd9620b8>,
#  'facebook bots': <gensim.models.keyedvectors.Vocab at 0x7efdcd9620f0>,
#  'software bot': <gensim.models.keyedvectors.Vocab at 0x7efdcd962128>,
#  'neurocomputational speech processing': <gensim.models.keyedvectors.Vocab at 0x7efdcd962160>,
#  'deterministic global optimization': <gensim.models.keyedvectors.Vocab at 0x7efdcd962198>,
#  'goal programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd9621d0>,
#  'curve fitting': <gensim.models.keyedvectors.Vocab at 0x7efdcd962208>,
#  'mathematical optimization society': <gensim.models.keyedvectors.Vocab at 0x7efdcd962240>,
#  'memristor': <gensim.models.keyedvectors.Vocab at 0x7efdcd962278>,
#  'customer analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9622b0>,
#  'systemic functional linguistics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9622e8>,
#  'semantic social network': <gensim.models.keyedvectors.Vocab at 0x7efdcd962320>,
#  'semantic matching': <gensim.models.keyedvectors.Vocab at 0x7efdcd962358>,
#  'linked data': <gensim.models.keyedvectors.Vocab at 0x7efdcd962390>,
#  'business semantics management': <gensim.models.keyedvectors.Vocab at 0x7efdcd9623c8>,
#  'smart-m3': <gensim.models.keyedvectors.Vocab at 0x7efdcd962400>,
#  'web ontology language': <gensim.models.keyedvectors.Vocab at 0x7efdcd962438>,
#  'agris': <gensim.models.keyedvectors.Vocab at 0x7efdcd9624a8>,
#  'ontology learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd9624e0>,
#  'internet of things': <gensim.models.keyedvectors.Vocab at 0x7efdcd962518>,
#  'resource description framework': <gensim.models.keyedvectors.Vocab at 0x7efdcd962550>,
#  'quantitative linguistics': <gensim.models.keyedvectors.Vocab at 0x7efdcd962588>,
#  'translation memory': <gensim.models.keyedvectors.Vocab at 0x7efdcd9625c0>,
#  'human speechome project': <gensim.models.keyedvectors.Vocab at 0x7efdcd9625f8>,
#  'computational semiotics': <gensim.models.keyedvectors.Vocab at 0x7efdcd962630>,
#  "mark a. o'neill": <gensim.models.keyedvectors.Vocab at 0x7efdcd962668>,
#  'mathematical model': <gensim.models.keyedvectors.Vocab at 0x7efdcd9626a0>,
#  'pandemonium architecture': <gensim.models.keyedvectors.Vocab at 0x7efdcd9626d8>,
#  'c (programming language)': <gensim.models.keyedvectors.Vocab at 0x7efdcd962710>,
#  'interaction design foundation': <gensim.models.keyedvectors.Vocab at 0x7efdcd962748>,
#  'usability': <gensim.models.keyedvectors.Vocab at 0x7efdcd962780>,
#  'web literacy': <gensim.models.keyedvectors.Vocab at 0x7efdcd9627b8>,
#  'digital humanities': <gensim.models.keyedvectors.Vocab at 0x7efdcd9627f0>,
#  'card sorting': <gensim.models.keyedvectors.Vocab at 0x7efdcd962828>,
#  'process architecture': <gensim.models.keyedvectors.Vocab at 0x7efdcd962860>,
#  'web-based simulation': <gensim.models.keyedvectors.Vocab at 0x7efdcd962898>,
#  "conway's game of life": <gensim.models.keyedvectors.Vocab at 0x7efdcd9628d0>,
#  'sociophysics': <gensim.models.keyedvectors.Vocab at 0x7efdcd962908>,
#  'probabilistic latent semantic analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd962940>,
#  'explicit semantic analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd962978>,
#  'thomas landauer': <gensim.models.keyedvectors.Vocab at 0x7efdcd9629b0>,
#  'word embedding': <gensim.models.keyedvectors.Vocab at 0x7efdcd9629e8>,
#  'scott deerwester': <gensim.models.keyedvectors.Vocab at 0x7efdcd962a20>,
#  'random indexing': <gensim.models.keyedvectors.Vocab at 0x7efdcd962a58>,
#  'new epoch notation painting': <gensim.models.keyedvectors.Vocab at 0x7efdcd962a90>,
#  'signage': <gensim.models.keyedvectors.Vocab at 0x7efdcd962b00>,
#  'data management': <gensim.models.keyedvectors.Vocab at 0x7efdcd962b38>,
#  'distributed artificial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd962b70>,
#  'q-learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd962ba8>,
#  'optimal control': <gensim.models.keyedvectors.Vocab at 0x7efdcd962be0>,
#  'dynamic treatment regimes': <gensim.models.keyedvectors.Vocab at 0x7efdcd962c18>,
#  'semantic heterogeneity': <gensim.models.keyedvectors.Vocab at 0x7efdcd962c50>,
#  'radial basis function kernel': <gensim.models.keyedvectors.Vocab at 0x7efdcd962c88>,
#  'tuple space': <gensim.models.keyedvectors.Vocab at 0x7efdcd962cc0>,
#  'reservoir computing': <gensim.models.keyedvectors.Vocab at 0x7efdcd962cf8>,
#  'principal components analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd962d30>,
#  'personal information management': <gensim.models.keyedvectors.Vocab at 0x7efdcd962d68>,
#  'web mining': <gensim.models.keyedvectors.Vocab at 0x7efdcd962da0>,
#  'logistic regression': <gensim.models.keyedvectors.Vocab at 0x7efdcd962dd8>,
#  'memory network': <gensim.models.keyedvectors.Vocab at 0x7efdcd962e10>,
#  'existential risk from artificial general intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd962e48>,
#  'global issue': <gensim.models.keyedvectors.Vocab at 0x7efdcd962e80>,
#  'arms race': <gensim.models.keyedvectors.Vocab at 0x7efdcd962eb8>,
#  'ethics of artificial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd962ef0>,
#  'attempto controlled english': <gensim.models.keyedvectors.Vocab at 0x7efdcd962f28>,
#  'structured query language': <gensim.models.keyedvectors.Vocab at 0x7efdcd962f60>,
#  'decision field theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd962f98>,
#  'educational neuroscience': <gensim.models.keyedvectors.Vocab at 0x7efdcd962fd0>,
#  'cognitive anthropology': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b048>,
#  'human cognome project': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b080>,
#  'heterophenomenology': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b0b8>,
#  'trade-off talking rational economic person': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b0f0>,
#  'active intellect': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b128>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b160>,
#  'cattell–horn–carroll theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b198>,
#  'intellect': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b1d0>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b208>,
#  'passive intellect': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b240>,
#  'intelligence (journal)': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b278>,
#  'black box': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b2b0>,
#  'latent semantic structure indexing': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b2e8>,
#  'natural-language programming': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b320>,
#  'disease surveillance': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b358>,
#  'software-defined radio': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b390>,
#  'channel allocation schemes': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b3c8>,
#  'ofdma': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b438>,
#  'cognitive network': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b470>,
#  'channel-dependent scheduling': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b4a8>,
#  'tv white space database': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b4e0>,
#  '3d interaction': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b518>,
#  'real options valuation': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b550>,
#  'system dynamics': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b588>,
#  'agent communications language': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b5c0>,
#  'strong artificial intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b5f8>,
#  'sonification': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b630>,
#  'cognitive modeling': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b668>,
#  'biosemiotics': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b6a0>,
#  'nonlinear system identification': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b6d8>,
#  'human brain project': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b710>,
#  'defeasible reasoning': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b748>,
#  'superintelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b780>,
#  'neuroscience and intelligence': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b7b8>,
#  'spamdexing': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b7f0>,
#  'latent dirichlet allocation': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b828>,
#  'genexprotools': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b860>,
#  'error-driven learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b898>,
#  'fictitious play': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b8d0>,
#  'botnet': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b940>,
#  'complex systems': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b978>,
#  'genetic representation': <gensim.models.keyedvectors.Vocab at 0x7efdcd96b9b0>,
#  'cma-es': <gensim.models.keyedvectors.Vocab at 0x7efdcd96ba20>,
#  'concept mining': <gensim.models.keyedvectors.Vocab at 0x7efdcd96ba58>,
#  'speech-language pathology': <gensim.models.keyedvectors.Vocab at 0x7efdcd96ba90>,
#  'embodied cognitive science': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bac8>,
#  'joone': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bb38>,
#  'deeplearning4j': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bb70>,
#  'project joshua blue': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bba8>,
#  'tektology': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bbe0>,
#  'viable system theory': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bc18>,
#  'superorganism': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bc50>,
#  'predictive engineering analytics': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bc88>,
#  'covariance matrix adaptation with hypervolume sorted adaptive grid algorithm': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bcc0>,
#  'es-hyperneat': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bcf8>,
#  'noogenesis': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bd30>,
#  'notation in probability and statistics': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bd68>,
#  'statistical analysis': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bda0>,
#  'foundations of statistics': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bdd8>,
#  'craftivism': <gensim.models.keyedvectors.Vocab at 0x7efdcd96be10>,
#  'urban informatics': <gensim.models.keyedvectors.Vocab at 0x7efdcd96be48>,
#  'data philanthropy': <gensim.models.keyedvectors.Vocab at 0x7efdcd96be80>,
#  'human-based evolutionary computation': <gensim.models.keyedvectors.Vocab at 0x7efdcd96beb8>,
#  'evolutionary robotics': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bef0>,
#  'adaptive dimensional search': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bf28>,
#  'environmentalism': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bf60>,
#  'scientific consensus on climate change': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bf98>,
#  'lexicostatistics': <gensim.models.keyedvectors.Vocab at 0x7efdcd96bfd0>,
#  'computational linguistics (journal)': <gensim.models.keyedvectors.Vocab at 0x7efdcd975048>,
#  'glottochronology': <gensim.models.keyedvectors.Vocab at 0x7efdcd975080>,
#  'internet linguistics': <gensim.models.keyedvectors.Vocab at 0x7efdcd9750b8>,
#  'computational lexicology': <gensim.models.keyedvectors.Vocab at 0x7efdcd9750f0>,
#  'dialog systems': <gensim.models.keyedvectors.Vocab at 0x7efdcd975128>,
#  'situated cognition': <gensim.models.keyedvectors.Vocab at 0x7efdcd975160>,
#  'simulation argument': <gensim.models.keyedvectors.Vocab at 0x7efdcd975198>,
#  'social dividend': <gensim.models.keyedvectors.Vocab at 0x7efdcd9751d0>,
#  'work–life balance': <gensim.models.keyedvectors.Vocab at 0x7efdcd975208>,
#  'fairtax': <gensim.models.keyedvectors.Vocab at 0x7efdcd975278>,
#  'software art': <gensim.models.keyedvectors.Vocab at 0x7efdcd9752b0>,
#  'cognitive dimensions of notations': <gensim.models.keyedvectors.Vocab at 0x7efdcd9752e8>,
#  'visual reasoning': <gensim.models.keyedvectors.Vocab at 0x7efdcd975320>,
#  'representation learning': <gensim.models.keyedvectors.Vocab at 0x7efdcd975358>,
#  ...}

# %%
container = widgets.HBox(children=[textbox_query, selector])
widgets.VBox([title, annotations, container, query_answer, g])
# Out:
# VBox(children=(HTML(value='<h3> Wikipedia Recommender System </h3>'), HTML(value='<h4> By clicking on a node, …
